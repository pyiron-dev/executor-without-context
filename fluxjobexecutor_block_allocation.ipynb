# %%
from executorlib import FluxJobExecutor
from time import sleep

# %%
funct_str = """
from time import sleep

def echo_with_delay(i):
    sleep(10)
    return i
"""

# %%
with open("myfunctions.py", "w") as f:
    f.write(funct_str)

# %%
from myfunctions import echo_with_delay

# %% [markdown]
# # wait=True and cancel_futures=False

# %%
exe = FluxJobExecutor(max_workers=1, block_allocation=True)
f1 = exe.submit(echo_with_delay, 1)
f2 = exe.submit(echo_with_delay, 2)
f3 = exe.submit(echo_with_delay, 3)
exe.shutdown(wait=True, cancel_futures=False)

# %%
f1.done(), f2.done(), f3.done(), f1.cancelled(), f2.cancelled(), f3.cancelled()
# Out:
# (True, True, True, False, False, False)

# %%
# !flux jobs -a
# Out:
#        JOBID USER     NAME       ST NTASKS NNODES     TIME INFO
#      ƒjsEEbH jovyan   python     CD      1      1   30.26s jupyter-pyiron-dev-exec-without-context-zwkbpvwb

# %%
sleep(12)

# %%
# !flux jobs -a
# Out:
#        JOBID USER     NAME       ST NTASKS NNODES     TIME INFO
#      ƒjsEEbH jovyan   python     CD      1      1   30.26s jupyter-pyiron-dev-exec-without-context-zwkbpvwb

# %%
f1.done(), f2.done(), f3.done(), f1.cancelled(), f2.cancelled(), f3.cancelled()
# Out:
# (True, True, True, False, False, False)

# %% [markdown]
# # wait=False and cancel_futures=False

# %%
exe = FluxJobExecutor(max_workers=1, block_allocation=True)
f1 = exe.submit(echo_with_delay, 1)
f2 = exe.submit(echo_with_delay, 2)
f3 = exe.submit(echo_with_delay, 3)
exe.shutdown(wait=False, cancel_futures=False)

# %%
f1.done(), f2.done(), f3.done(), f1.cancelled(), f2.cancelled(), f3.cancelled()
# Out:
# (False, False, False, False, False, False)

# %%
# !flux jobs -a
# Out:
#        JOBID USER     NAME       ST NTASKS NNODES     TIME INFO
#     ƒMTSpFNX jovyan   python      R      1      1   0.820s jupyter-pyiron-dev-exec-without-context-zwkbpvwb
#      ƒjsEEbH jovyan   python     CD      1      1   30.26s jupyter-pyiron-dev-exec-without-context-zwkbpvwb

# %%
sleep(12)

# %%
# !flux jobs -a
# Out:
#        JOBID USER     NAME       ST NTASKS NNODES     TIME INFO
#     ƒMTSpFNX jovyan   python      R      1      1   13.71s jupyter-pyiron-dev-exec-without-context-zwkbpvwb
#      ƒjsEEbH jovyan   python     CD      1      1   30.26s jupyter-pyiron-dev-exec-without-context-zwkbpvwb

# %%
f1.done(), f2.done(), f3.done(), f1.cancelled(), f2.cancelled(), f3.cancelled()
# Out:
# (True, False, False, False, False, False)

# %% [markdown]
# # wait=False and cancel_futures=True - interrupts during run time

# %%
exe = FluxJobExecutor(max_workers=1, block_allocation=True)
f1 = exe.submit(echo_with_delay, 1)
f2 = exe.submit(echo_with_delay, 2)
f3 = exe.submit(echo_with_delay, 3)
exe.shutdown(wait=False, cancel_futures=True)

# %%
f1.done(), f2.done(), f3.done(), f1.cancelled(), f2.cancelled(), f3.cancelled()
# Out:
# (True, True, True, True, True, True)

# %%
# !flux jobs -a
# Out:
#        JOBID USER     NAME       ST NTASKS NNODES     TIME INFO
#     ƒMTSpFNX jovyan   python      R      1      1   15.04s jupyter-pyiron-dev-exec-without-context-zwkbpvwb
#     ƒTmFX3KM jovyan   python     CD      1      1   0.458s jupyter-pyiron-dev-exec-without-context-zwkbpvwb
#      ƒjsEEbH jovyan   python     CD      1      1   30.26s jupyter-pyiron-dev-exec-without-context-zwkbpvwb

# %%
sleep(12)

# %%
# !flux jobs -a
# Out:
#        JOBID USER     NAME       ST NTASKS NNODES     TIME INFO
#     ƒMTSpFNX jovyan   python      R      1      1   27.95s jupyter-pyiron-dev-exec-without-context-zwkbpvwb
#     ƒTmFX3KM jovyan   python     CD      1      1   0.458s jupyter-pyiron-dev-exec-without-context-zwkbpvwb
#      ƒjsEEbH jovyan   python     CD      1      1   30.26s jupyter-pyiron-dev-exec-without-context-zwkbpvwb

# %%
f1.done(), f2.done(), f3.done(), f1.cancelled(), f2.cancelled(), f3.cancelled()
# Out:
# (True, True, True, True, True, True)

# %% [markdown]
# # wait=True and cancel_futures=True - interrupts during run time

# %%
exe = FluxJobExecutor(max_workers=1, block_allocation=True)
f1 = exe.submit(echo_with_delay, 1)
f2 = exe.submit(echo_with_delay, 2)
f3 = exe.submit(echo_with_delay, 3)
exe.shutdown(wait=True, cancel_futures=True)

# %%
f1.done(), f2.done(), f3.done(), f1.cancelled(), f2.cancelled(), f3.cancelled()
# Out:
# (True, True, True, True, True, True)

# %%
# !flux jobs -a
# Out:
#        JOBID USER     NAME       ST NTASKS NNODES     TIME INFO
#     ƒMTSpFNX jovyan   python      R      1      1   29.44s jupyter-pyiron-dev-exec-without-context-zwkbpvwb
#     ƒZyP6ahd jovyan   python     CD      1      1   0.184s jupyter-pyiron-dev-exec-without-context-zwkbpvwb
#     ƒTmFX3KM jovyan   python     CD      1      1   0.458s jupyter-pyiron-dev-exec-without-context-zwkbpvwb
#      ƒjsEEbH jovyan   python     CD      1      1   30.26s jupyter-pyiron-dev-exec-without-context-zwkbpvwb

# %%
sleep(12)

# %%
# !flux jobs -a
# Out:
#        JOBID USER     NAME       ST NTASKS NNODES     TIME INFO
#     ƒMTSpFNX jovyan   python     CD      1      1    30.7s jupyter-pyiron-dev-exec-without-context-zwkbpvwb
#     ƒZyP6ahd jovyan   python     CD      1      1   0.184s jupyter-pyiron-dev-exec-without-context-zwkbpvwb
#     ƒTmFX3KM jovyan   python     CD      1      1   0.458s jupyter-pyiron-dev-exec-without-context-zwkbpvwb
#      ƒjsEEbH jovyan   python     CD      1      1   30.26s jupyter-pyiron-dev-exec-without-context-zwkbpvwb

# %%
f1.done(), f2.done(), f3.done(), f1.cancelled(), f2.cancelled(), f3.cancelled()
# Out:
# (True, True, True, True, True, True)
